# %% [markdown]
# # 03 — Performance Analysis
# Pregunta: ¿qué rentabilidad produjo el portafolio a lo largo del tiempo?
#
# Requiere una serie histórica de valor o flujos que todavía no está incluida.
